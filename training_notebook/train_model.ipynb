# %%
# Imports 
import os
import numpy as np 
import pandas as pd
from PIL import Image
from tqdm import tqdm
import matplotlib.pyplot as plt

import keras 
from keras import Sequential
from keras.utils import to_categorical
from keras.callbacks import ReduceLROnPlateau,ModelCheckpoint
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Conv2D, Flatten, BatchNormalization, Dropout, Activation, MaxPooling2D, GlobalAveragePooling2D

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
expression_header = ['neutral', 'happiness', 'surprise', 'sadness', 'anger', 'disgust', 'fear', 'contempt', 'unknown', 'NF']

# %%
# load the data
base_path = '/kaggle/input/ferplus/FER2013Plus'

test_folder = 'FER2013Test'
train_folder = 'FER2013Train'
valid_folder = 'FER2013Valid'

labels = {
    'train' : pd.read_csv(os.path.join(base_path, 'Labels', train_folder, 'label.csv'), names=expression_header),
    'test' : pd.read_csv(os.path.join(base_path, 'Labels', test_folder, 'label.csv'), names=expression_header),
    'valid' : pd.read_csv(os.path.join(base_path, 'Labels', valid_folder, 'label.csv'), names=expression_header)
}

y_train = labels['train'][expression_header].values / 10
y_test = labels['test'][expression_header].values / 10
y_val = labels['valid'][expression_header].values / 10

print(y_train.shape, y_test.shape, y_val.shape)
# Out:
# (28558, 10) (3573, 10) (3579, 10)

# %%
# load images
X_train, X_test, X_val = [], [], []

for idx, row in tqdm(labels['train'].iterrows(), desc='training images : ', unit='img', total=labels['train'].index.size):
    img_path = os.path.join(base_path, 'Images', train_folder, idx[0])
    img = np.asarray(
            Image.open(
                img_path
            ).convert("L")
        )
    X_train.append(img)

for idx, row in tqdm(labels['test'].iterrows(), desc='testing images : ', unit='img', total=labels['test'].index.size):
    img_path = os.path.join(base_path, 'Images', test_folder, idx[0])
    img = np.asarray(
            Image.open(
                img_path
            ).convert("L")
        )
    X_test.append(img)

for idx, row in tqdm(labels['valid'].iterrows(), desc='validation images : ', unit='img', total=labels['valid'].index.size):
    img_path = os.path.join(base_path, 'Images', valid_folder, idx[0])
    img = np.asarray(
            Image.open(
                img_path
            ).convert("L")
        )
    X_val.append(img)
        
X_train, X_test, X_val = np.array(X_train), np.array(X_test), np.array(X_val)
# Out:
# training images : 100%|██████████| 28558/28558 [01:50<00:00, 257.86img/s]
# testing images : 100%|██████████| 3573/3573 [00:13<00:00, 274.46img/s]
# validation images : 100%|██████████| 3579/3579 [00:12<00:00, 283.16img/s]

# %%
idx = 10
print(' '.join(f'{expr}:{prb}' for expr, prb in zip(expression_header, y_test[idx])))
plt.title(expression_header[np.argmax(y_test[idx])])
plt.imshow(X_test[idx], cmap='gray', vmin=0, vmax=255)
# Out:
# neutral:0.0 happiness:1.0 surprise:0.0 sadness:0.0 anger:0.0 disgust:0.0 fear:0.0 contempt:0.0 unknown:0.0 NF:0.0

# %%
# Reshpae the data
X_train = X_train.reshape(-1,48,48,1)
X_test = X_test.reshape(-1,48,48,1)

# Normalization 255 => (-1,1)
X_train = (X_train-127.5)/127.5
X_test = (X_test-127.5)/127.5

# %%
# model
model = Sequential()
params = {
    'kernel_size':(3,3), 'strides':(1,1), 'padding':'valid', 'activation':None, 'use_bias':False
}
model.add(Conv2D(filters=32, input_shape=(X_train.shape[1:]), **params))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(Conv2D(filters=64, **params))
model.add(Dropout(rate=0.5))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(filters=96, **params))
model.add(Dropout(rate=0.5))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(Conv2D(filters=128, **params))
model.add(Dropout(rate=0.5))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(filters=156, **params))
model.add(Dropout(rate=0.5))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(GlobalAveragePooling2D())
model.add(Flatten())   
model.add(Dense(units=10))
model.add(BatchNormalization())
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy', 
            optimizer='adam', 
            metrics=['accuracy']
)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 46, 46, 32)        288
#
#  batch_normalization (Batch  (None, 46, 46, 32)        128
#  Normalization)
#
#  activation (Activation)     (None, 46, 46, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 44, 44, 64)        18432
#
#  dropout (Dropout)           (None, 44, 44, 64)        0
#
#  batch_normalization_1 (Bat  (None, 44, 44, 64)        256
#  chNormalization)
#
#  activation_1 (Activation)   (None, 44, 44, 64)        0
#
#  max_pooling2d (MaxPooling2  (None, 22, 22, 64)        0
#  D)
#
#  conv2d_2 (Conv2D)           (None, 20, 20, 96)        55296
#
#  dropout_1 (Dropout)         (None, 20, 20, 96)        0
#
#  batch_normalization_2 (Bat  (None, 20, 20, 96)        384
#  chNormalization)
#
#  activation_2 (Activation)   (None, 20, 20, 96)        0
#
#  conv2d_3 (Conv2D)           (None, 18, 18, 128)       110592
#
#  dropout_2 (Dropout)         (None, 18, 18, 128)       0
#
#  batch_normalization_3 (Bat  (None, 18, 18, 128)       512
#  chNormalization)
#
#  activation_3 (Activation)   (None, 18, 18, 128)       0
#
#  max_pooling2d_1 (MaxPoolin  (None, 9, 9, 128)         0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 7, 7, 156)         179712
#
#  dropout_3 (Dropout)         (None, 7, 7, 156)         0
#
#  batch_normalization_4 (Bat  (None, 7, 7, 156)         624
#  chNormalization)
#
#  activation_4 (Activation)   (None, 7, 7, 156)         0
#
#  global_average_pooling2d (  (None, 156)               0
#  GlobalAveragePooling2D)
#
#  flatten (Flatten)           (None, 156)               0
#
#  dense (Dense)               (None, 10)                1570
#
#  batch_normalization_5 (Bat  (None, 10)                40
#  chNormalization)
#
#  activation_5 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 367834 (1.40 MB)
# Trainable params: 366862 (1.40 MB)
# Non-trainable params: 972 (3.80 KB)
# _________________________________________________________________

# %%
reduceLROnPlateau = ReduceLROnPlateau(monitor='val_acc', 
                                patience=3,
                                verbose=1, 
                                factor=0.1,
                                min_lr=0.00001)

# %%
history = model.fit(X_train[:20000], y_train[:20000],
                  batch_size=128,
                  epochs=25,
                  callbacks=[reduceLROnPlateau, ModelCheckpoint("best_model.h5", save_best_only=True)], 
                  validation_data=(X_train[20000:], y_train[20000:])
        )
# Out:
# Epoch 1/25
# 157/157 [==============================] - 270s 2s/step - loss: 1.0382 - accuracy: 0.7919 - val_loss: 1.1341 - val_accuracy: 0.7518 - lr: 0.0010
# Epoch 2/25
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 157/157 [==============================] - 262s 2s/step - loss: 1.0191 - accuracy: 0.8034 - val_loss: 1.1415 - val_accuracy: 0.7525 - lr: 0.0010
# Epoch 3/25
# 157/157 [==============================] - 263s 2s/step - loss: 1.0130 - accuracy: 0.8040 - val_loss: 1.1555 - val_accuracy: 0.7413 - lr: 0.0010
# Epoch 4/25
# 157/157 [==============================] - 263s 2s/step - loss: 1.0136 - accuracy: 0.8061 - val_loss: 1.1210 - val_accuracy: 0.7749 - lr: 0.0010
# Epoch 5/25
# 157/157 [==============================] - 263s 2s/step - loss: 1.0066 - accuracy: 0.8088 - val_loss: 1.1854 - val_accuracy: 0.7369 - lr: 0.0010
# Epoch 6/25
# 157/157 [==============================] - 266s 2s/step - loss: 1.0092 - accuracy: 0.8106 - val_loss: 1.1771 - val_accuracy: 0.7442 - lr: 0.0010
# Epoch 7/25
# 157/157 [==============================] - 268s 2s/step - loss: 1.0032 - accuracy: 0.8152 - val_loss: 1.1848 - val_accuracy: 0.7309 - lr: 0.0010
# Epoch 8/25
# 157/157 [==============================] - 262s 2s/step - loss: 1.0035 - accuracy: 0.8086 - val_loss: 1.1601 - val_accuracy: 0.7512 - lr: 0.0010
# Epoch 9/25
# 157/157 [==============================] - 259s 2s/step - loss: 1.0036 - accuracy: 0.8123 - val_loss: 1.1509 - val_accuracy: 0.7488 - lr: 0.0010
# Epoch 10/25
# 157/157 [==============================] - 263s 2s/step - loss: 0.9971 - accuracy: 0.8170 - val_loss: 1.1969 - val_accuracy: 0.7325 - lr: 0.0010
# Epoch 11/25
# 157/157 [==============================] - 261s 2s/step - loss: 0.9990 - accuracy: 0.8164 - val_loss: 1.2565 - val_accuracy: 0.6843 - lr: 0.0010
# Epoch 12/25
# 157/157 [==============================] - 261s 2s/step - loss: 0.9983 - accuracy: 0.8143 - val_loss: 1.0957 - val_accuracy: 0.7782 - lr: 0.0010
# Epoch 13/25
# 157/157 [==============================] - 269s 2s/step - loss: 0.9965 - accuracy: 0.8146 - val_loss: 1.1013 - val_accuracy: 0.7710 - lr: 0.0010
# Epoch 14/25
# 157/157 [==============================] - 276s 2s/step - loss: 0.9926 - accuracy: 0.8174 - val_loss: 1.1107 - val_accuracy: 0.7675 - lr: 0.0010
# Epoch 15/25
# 157/157 [==============================] - 272s 2s/step - loss: 0.9944 - accuracy: 0.8181 - val_loss: 1.1237 - val_accuracy: 0.7647 - lr: 0.0010
# Epoch 16/25
# 157/157 [==============================] - 263s 2s/step - loss: 0.9902 - accuracy: 0.8182 - val_loss: 1.1297 - val_accuracy: 0.7661 - lr: 0.0010
# Epoch 17/25
# 157/157 [==============================] - 260s 2s/step - loss: 0.9910 - accuracy: 0.8147 - val_loss: 1.1436 - val_accuracy: 0.7556 - lr: 0.0010
# Epoch 18/25
# 157/157 [==============================] - 264s 2s/step - loss: 0.9862 - accuracy: 0.8212 - val_loss: 1.1360 - val_accuracy: 0.7616 - lr: 0.0010
# Epoch 19/25
# 157/157 [==============================] - 264s 2s/step - loss: 0.9851 - accuracy: 0.8208 - val_loss: 1.2138 - val_accuracy: 0.7073 - lr: 0.0010
# Epoch 20/25
# 157/157 [==============================] - 261s 2s/step - loss: 0.9852 - accuracy: 0.8225 - val_loss: 1.1486 - val_accuracy: 0.7512 - lr: 0.0010
# Epoch 21/25
# 157/157 [==============================] - 261s 2s/step - loss: 0.9818 - accuracy: 0.8233 - val_loss: 1.3095 - val_accuracy: 0.6804 - lr: 0.0010
# Epoch 22/25
# 157/157 [==============================] - 264s 2s/step - loss: 0.9833 - accuracy: 0.8247 - val_loss: 1.1520 - val_accuracy: 0.7527 - lr: 0.0010
# Epoch 23/25
# 157/157 [==============================] - 264s 2s/step - loss: 0.9826 - accuracy: 0.8234 - val_loss: 1.1249 - val_accuracy: 0.7689 - lr: 0.0010
# Epoch 24/25
# 157/157 [==============================] - 267s 2s/step - loss: 0.9814 - accuracy: 0.8228 - val_loss: 1.1506 - val_accuracy: 0.7546 - lr: 0.0010
# Epoch 25/25
# 157/157 [==============================] - 260s 2s/step - loss: 0.9798 - accuracy: 0.8240 - val_loss: 1.1433 - val_accuracy: 0.7674 - lr: 0.0010

# %%
model.evaluate(X_test, y_test)
# Out:
# 112/112 [==============================] - 8s 69ms/step - loss: 1.1619 - accuracy: 0.7495
# [1.1619404554367065, 0.7495102286338806]

# %%
model.save("model_0.h5")

# %%
# history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'])
plt.show()
